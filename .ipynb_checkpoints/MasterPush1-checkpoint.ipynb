# %%
import requests
import json
import pprint
import time
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import numpy as np

url = "https://www.alphavantage.co/query"

function = "TIME_SERIES_DAILY"
symbol = "ATVI"
api_key = "FS9AIROSBH4ZBEHY"
output = "full"

data = { "function": function,
        "symbol": symbol,
        "apikey": api_key,
        "outputsize": output} 
page = requests.get(url, params = data)
pprint.pprint(page.json())
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices (open, high, low, close) and '
#                                  'Volumes',
#                '2. Symbol': 'ATVI',
#                '3. Last Refreshed': '2018-01-09',
#                '4. Output Size': 'Full size',
#                '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2000-01-03': {'1. open': '15.7500',
#                                         '2. high': '16.5000',
#                                         '3. low': '14.0000',
#                                         '4. close': '16.4400',
#                                         '5. volume': '602150'},
#                          '2000-01-04': {'1. open': '16.1200',
#                                         '2. high': '16.2500',
#                                         '3. low': '14.2500',
#                                         '4. close': '15.9400',
#                                         '5. volume': '355200'},
#                          '2000-01-05': {'1. open': '15.8100',
#                                         '2. high': '16.3700',
#                                         '3. low': '15.7500',
#                                         '4. close': '16.0000',
#                                         '5. volume': '282417'},
#                          '2000-01-06': {'1. open': '15.8800',
#                                         '2. high': '16.0000',
#                                         '3. low': '15.5600',
#                                         '4. close': '15.6900',
#                                         '5. volume': '202417'},
#                          '2000-01-07': {'1. open': '15.8800',
#                                         '2. high': '16.2500',
#                                         '3. low': '15.5000',
#                                         '4. close': '16.1200',
#                                         '5. volume': '1295750'},
#                          '2000-01-10': {'1. open': '16.2500',
#                                         '2. high': '17.0000',
#                                         '3. low': '15.8800',
#                                         '4. close': '16.9400',
#                                         '5. volume': '912550'},
#                          '2000-01-11': {'1. open': '17.0000',
#                                         '2. high': '18.2500',
#                                         '3. low': '16.8800',
#                                         '4. close': '17.6900',
#                                         '5. volume': '892550'},
#                          '2000-01-12': {'1. open': '17.2500',
#                                         '2. high': '17.2500',
#                                         '3. low': '16.3700',
#                                         '4. close': '16.9400',
#                                         '5. volume': '224017'},
#                          '2000-01-13': {'1. open': '16.8800',
#                                         '2. high': '17.2500',
#                                         '3. low': '16.5000',
#                                         '4. close': '17.1200',
#                                         '5. volume': '272267'},
#                          '2000-01-14': {'1. open': '16.8800',
#                                         '2. high': '17.1200',
#                                         '3. low': '16.6900',
#                                         '4. close': '16.9400',
#                                         '5. volume': '212817'},
#                          '2000-01-18': {'1. open': '17.0000',
#                                         '2. high': '17.4400',
#                                         '3. low': '16.9400',
#                                         '4. close': '17.0000',
#                                         '5. volume': '205067'},
#                          '2000-01-19': {'1. open': '17.1200',
#                                         '2. high': '17.1200',
#                                         '3. low': '16.6900',
#                                         '4. close': '16.7500',
#                                         '5. volume': '299467'},
#                          '2000-01-20': {'1. open': '16.6300',
#                                         '2. high': '17.0000',
#                                         '3. low': '15.6200',
#                                         '4. close': '15.8100',
#                                         '5. volume': '444967'},
#                          '2000-01-21': {'1. open': '15.7800',
#                                         '2. high': '15.8100',
#                                         '3. low': '14.8700',
#                                         '4. close': '15.1300',
#                                         '5. volume': '955033'},
#                          '2000-01-24': {'1. open': '15.0300',
#                                         '2. high': '15.1900',
#                                         '3. low': '14.7500',
#                                         '4. close': '15.0000',
#                                         '5. volume': '421350'},
#                          '2000-01-25': {'1. open': '15.1300',
#                                         '2. high': '15.1300',
#                                         '3. low': '13.5900',
#                                         '4. close': '14.5000',
#                                         '5. volume': '509433'},
#                          '2000-01-26': {'1. open': '14.7500',
#                                         '2. high': '16.5000',
#                                         '3. low': '14.5000',
#                                         '4. close': '15.8800',
#                                         '5. volume': '978833'},
#                          '2000-01-27': {'1. open': '17.2500',
#                                         '2. high': '17.6200',
#                                         '3. low': '16.2500',
#                                         '4. close': '17.1900',
#                                         '5. volume': '779033'},
#                          '2000-01-28': {'1. open': '16.7500',
#                                         '2. high': '17.0000',
#                                         '3. low': '16.1200',
#                                         '4. close': '16.3700',
#                                         '5. volume': '242833'},
#                          '2000-01-31': {'1. open': '16.5600',
#                                         '2. high': '16.6300',
#                                         '3. low': '15.5000',
#                                         '4. close': '15.6200',
#                                         '5. volume': '122400'},
#                          '2000-02-01': {'1. open': '15.7800',
#                                         '2. high': '17.5000',
#                                         '3. low': '15.7500',
#                                         '4. close': '16.8800',
#                                         '5. volume': '192967'},
#                          '2000-02-02': {'1. open': '17.0000',
#                                         '2. high': '17.6900',
#                                         '3. low': '16.5000',
#                                         '4. close': '17.3800',
#                                         '5. volume': '515567'},
#                          '2000-02-03': {'1. open': '17.4400',
#                                         '2. high': '17.6200',
#                                         '3. low': '17.1900',
#                                         '4. close': '17.5600',
#                                         '5. volume': '541767'},
#                          '2000-02-04': {'1. open': '17.5300',
#                                         '2. high': '17.5600',
#                                         '3. low': '15.0000',
#                                         '4. close': '15.7500',
#                                         '5. volume': '2108267'},
#                          '2000-02-07': {'1. open': '15.1300',
#                                         '2. high': '15.3100',
#                                         '3. low': '14.9400',
#                                         '4. close': '15.0000',
#                                         '5. volume': '856633'},
#                          '2000-02-08': {'1. open': '15.1300',
#                                         '2. high': '15.2500',
#                                         '3. low': '14.2500',
#                                         '4. close': '14.7500',
#                                         '5. volume': '603750'},
#                          '2000-02-09': {'1. open': '14.7500',
#                                         '2. high': '14.9400',
#                                         '3. low': '14.3800',
#                                         '4. close': '14.5300',
#                                         '5. volume': '210833'},
#                          '2000-02-10': {'1. open': '14.8700',
#                                         '2. high': '14.8700',
#                                         '3. low': '14.3800',
#                                         '4. close': '14.4400',
#                                         '5. volume': '216633'},
#                          '2000-02-11': {'1. open': '14.7500',
#                                         '2. high': '15.0000',
#                                         '3. low': '14.5600',
#                                         '4. close': '14.8700',
#                                         '5. volume': '148967'},
#                          '2000-02-14': {'1. open': '14.8700',
#                                         '2. high': '15.0000',
#                                         '3. low': '14.2500',
#                                         '4. close': '14.3800',
#                                         '5. volume': '180367'},
#                          '2000-02-15': {'1. open': '14.5600',
#                                         '2. high': '14.5600',
#                                         '3. low': '14.0000',
#                                         '4. close': '14.0000',
#                                         '5. volume': '206233'},
#                          '2000-02-16': {'1. open': '14.3800',
#                                         '2. high': '14.6900',
#                                         '3. low': '14.0000',
#                                         '4. close': '14.0200',
#                                         '5. volume': '235033'},
#                          '2000-02-17': {'1. open': '14.3800',
#                                         '2. high': '14.5600',
#                                         '3. low': '14.0000',
#                                         '4. close': '14.0300',
#                                         '5. volume': '203200'},
#                          '2000-02-18': {'1. open': '14.2500',
#                                         '2. high': '14.5000',
#                                         '3. low': '12.6200',
#                                         '4. close': '13.5000',
#                                         '5. volume': '464550'},
#                          '2000-02-22': {'1. open': '13.5000',
#                                         '2. high': '13.8100',
#                                         '3. low': '13.0600',
#                                         '4. close': '13.3700',
#                                         '5. volume': '116433'},
#                          '2000-02-23': {'1. open': '13.5000',
#                                         '2. high': '13.5000',
#                                         '3. low': '12.8800',
#                                         '4. close': '13.0600',
#                                         '5. volume': '106150'},
#                          '2000-02-24': {'1. open': '13.2500',
#                                         '2. high': '13.2500',
#                                         '3. low': '12.7500',
#                                         '4. close': '13.1200',
#                                         '5. volume': '133617'},
#                          '2000-02-25': {'1. open': '13.2500',
#                                         '2. high': '13.2500',
#                                         '3. low': '12.6200',
#                                         '4. close': '12.7500',
#                                         '5. volume': '248800'},
#                          '2000-02-28': {'1. open': '12.6900',
#                                         '2. high': '12.8800',
#                                         '3. low': '12.5000',
#                                         '4. close': '12.5600',
#                                         '5. volume': '230233'},
#                          '2000-02-29': {'1. open': '12.5000',
#                                         '2. high': '12.8800',
#                                         '3. low': '12.5000',
#                                         '4. close': '12.6900',
#                                         '5. volume': '232800'},
#                          '2000-03-01': {'1. open': '12.8800',
#                                         '2. high': '15.0000',
#                                         '3. low': '12.7500',
#                                         '4. close': '14.5000',
#                                         '5. volume': '1367033'},
#                          '2000-03-02': {'1. open': '14.7800',
#                                         '2. high': '15.0000',
#                                         '3. low': '14.1200',
#                                         '4. close': '14.5000',
#                                         '5. volume': '203200'},
#                          '2000-03-03': {'1. open': '14.5000',
#                                         '2. high': '15.0600',
#                                         '3. low': '14.1200',
#                                         '4. close': '14.8100',
#                                         '5. volume': '1026667'},
#                          '2000-03-06': {'1. open': '15.0000',
#                                         '2. high': '15.0000',
#                                         '3. low': '14.2500',
#                                         '4. close': '14.3800',
#                                         '5. volume': '184817'},
#                          '2000-03-07': {'1. open': '14.5000',
#                                         '2. high': '14.8100',
#                                         '3. low': '13.1900',
#                                         '4. close': '13.7500',
#                                         '5. volume': '229867'},
#                          '2000-03-08': {'1. open': '13.7500',
#                                         '2. high': '13.7500',
#                                         '3. low': '13.1400',
#                                         '4. close': '13.1900',
#                                         '5. volume': '160367'},
#                          '2000-03-09': {'1. open': '13.5000',
#                                         '2. high': '14.4400',
#                                         '3. low': '13.4400',
#                                         '4. close': '14.4400',
#                                         '5. volume': '169767'},
#                          '2000-03-10': {'1. open': '14.4400',
#                                         '2. high': '14.8100',
#                                         '3. low': '14.2500',
#                                         '4. close': '14.3100',
#                                         '5. volume': '431200'},
#                          '2000-03-13': {'1. open': '14.5000',
#                                         '2. high': '14.5000',
#                                         '3. low': '13.5000',
#                                         '4. close': '13.5600',
#                                         '5. volume': '136017'},
#                          '2000-03-14': {'1. open': '13.8100',
#                                         '2. high': '14.0600',
#                                         '3. low': '13.0000',
#                                         '4. close': '13.8800',
#                                         '5. volume': '223750'},
#                          '2000-03-15': {'1. open': '14.0000',
#                                         '2. high': '14.0000',
#                                         '3. low': '12.8100',
#                                         '4. close': '13.0000',
#                                         '5. volume': '615567'},
#                          '2000-03-16': {'1. open': '13.7500',
#                                         '2. high': '13.7500',
#                                         '3. low': '12.9400',
#                                         '4. close': '13.0000',
#                                         '5. volume': '168550'},
#                          '2000-03-17': {'1. open': '12.8800',
#                                         '2. high': '13.6300',
#                                         '3. low': '12.8800',
#                                         '4. close': '13.0900',
#                                         '5. volume': '272800'},
#                          '2000-03-20': {'1. open': '13.2500',
#                                         '2. high': '14.1200',
#                                         '3. low': '13.1600',
#                                         '4. close': '13.5000',
#                                         '5. volume': '188967'},
#                          '2000-03-21': {'1. open': '13.8100',
#                                         '2. high': '14.0000',
#                                         '3. low': '13.2500',
#                                         '4. close': '13.4400',
#                                         '5. volume': '70033'},
#                          '2000-03-22': {'1. open': '13.6300',
#                                         '2. high': '13.9400',
#                                         '3. low': '13.3100',
#                                         '4. close': '13.3700',
#                                         '5. volume': '96367'},
#                          '2000-03-23': {'1. open': '13.3100',
#                                         '2. high': '13.5000',
#                                         '3. low': '12.6200',
#                                         '4. close': '12.8800',
#                                         '5. volume': '188800'},
#                          '2000-03-24': {'1. open': '13.0000',
#                                         '2. high': '13.6300',
#                                         '3. low': '12.7500',
#                                         '4. close': '13.6300',
#                                         '5. volume': '383217'},
#                          '2000-03-27': {'1. open': '13.3700',
#                                         '2. high': '13.6300',
#                                         '3. low': '13.1200',
#                                         '4. close': '13.1200',
#                                         '5. volume': '219467'},
#                          '2000-03-28': {'1. open': '13.2500',
#                                         '2. high': '13.5000',
#                                         '3. low': '13.1200',
#                                         '4. close': '13.1900',
#                                         '5. volume': '149233'},
#                          '2000-03-29': {'1. open': '13.2500',
#                                         '2. high': '13.5000',
#                                         '3. low': '12.7500',
#                                         '4. close': '13.1200',
#                                         '5. volume': '185867'},
#                          '2000-03-30': {'1. open': '13.0000',
#                                         '2. high': '13.0000',
#                                         '3. low': '12.8100',
#                                         '4. close': '12.8800',
#                                         '5. volume': '222033'},
#                          '2000-03-31': {'1. open': '13.0000',
#                                         '2. high': '13.0000',
#                                         '3. low': '11.6200',
#                                         '4. close': '12.0600',
#                                         '5. volume': '441967'},
#                          '2000-04-03': {'1. open': '12.1600',
#                                         '2. high': '12.1600',
#                                         '3. low': '10.6300',
#                                         '4. close': '11.1200',
#                                         '5. volume': '455833'},
#                          '2000-04-04': {'1. open': '11.1200',
#                                         '2. high': '11.1200',
#                                         '3. low': '10.2500',
#                                         '4. close': '10.6300',
#                                         '5. volume': '611633'},
#                          '2000-04-05': {'1. open': '10.3700',
#                                         '2. high': '11.2500',
#                                         '3. low': '10.1900',
#                                         '4. close': '10.6900',
#                                         '5. volume': '434033'},
#                          '2000-04-06': {'1. open': '10.7500',
#                                         '2. high': '11.3800',
#                                         '3. low': '10.6900',
#                                         '4. close': '11.0600',
#                                         '5. volume': '215200'},
#                          '2000-04-07': {'1. open': '11.0000',
#                                         '2. high': '11.0600',
#                                         '3. low': '7.6300',
#                                         '4. close': '8.0600',
#                                         '5. volume': '8546567'},
#                          '2000-04-10': {'1. open': '8.8700',
#                                         '2. high': '8.8700',
#                                         '3. low': '8.0000',
#                                         '4. close': '8.0600',
#                                         '5. volume': '1724633'},
#                          '2000-04-11': {'1. open': '8.0600',
#                                         '2. high': '8.1200',
#                                         '3. low': '6.7500',
#                                         '4. close': '7.0300',
#                                         '5. volume': '624267'},
#                          '2000-04-12': {'1. open': '7.1900',
#                                         '2. high': '7.3100',
#                                         '3. low': '6.3100',
#                                         '4. close': '6.9400',
#                                         '5. volume': '753067'},
#                          '2000-04-13': {'1. open': '7.0600',
#                                         '2. high': '7.1200',
#                                         '3. low': '6.8100',
#                                         '4. close': '6.8800',
#                                         '5. volume': '222150'},
#                          '2000-04-14': {'1. open': '6.6900',
#                                         '2. high': '6.7500',
#                                         '3. low': '6.3800',
#                                         '4. close': '6.5000',
#                                         '5. volume': '531033'},
#                          '2000-04-17': {'1. open': '6.5000',
#                                         '2. high': '6.5600',
#                                         '3. low': '5.8700',
#                                         '4. close': '6.3800',
#                                         '5. volume': '1138767'},
#                          '2000-04-18': {'1. open': '6.3100',
#                                         '2. high': '6.5600',
#                                         '3. low': '6.0000',
#                                         '4. close': '6.3100',
#                                         '5. volume': '442667'},
#                          '2000-04-19': {'1. open': '6.6200',
#                                         '2. high': '6.6900',
#                                         '3. low': '6.1900',
#                                         '4. close': '6.2200',
#                                         '5. volume': '232800'},
#                          '2000-04-20': {'1. open': '6.2500',
#                                         '2. high': '6.6900',
#                                         '3. low': '6.2500',
#                                         '4. close': '6.6900',
#                                         '5. volume': '1061767'},
#                          '2000-04-24': {'1. open': '6.6200',
#                                         '2. high': '6.7500',
#                                         '3. low': '6.3100',
#                                         '4. close': '6.5600',
#                                         '5. volume': '296817'},
#                          '2000-04-25': {'1. open': '6.6900',
#                                         '2. high': '7.0000',
#                                         '3. low': '6.2500',
#                                         '4. close': '6.9100',
#                                         '5. volume': '2629967'},
#                          '2000-04-26': {'1. open': '7.0600',
#                                         '2. high': '7.3100',
#                                         '3. low': '6.6600',
#                                         '4. close': '6.6700',
#                                         '5. volume': '460550'},
#                          '2000-04-27': {'1. open': '6.7500',
#                                         '2. high': '6.7800',
#                                         '3. low': '6.6200',
#                                         '4. close': '6.7500',
#                                         '5. volume': '460433'},
#                          '2000-04-28': {'1. open': '6.9700',
#                                         '2. high': '7.0000',
#                                         '3. low': '6.1300',
#                                         '4. close': '6.2500',
#                                         '5. volume': '774767'},
#                          '2000-05-01': {'1. open': '6.5000',
#                                         '2. high': '6.9700',
#                                         '3. low': '6.2500',
#                                         '4. close': '6.2500',
#                                         '5. volume': '1034400'},
#                          '2000-05-02': {'1. open': '6.5600',
#                                         '2. high': '7.1200',
#                                         '3. low': '6.4400',
#                                         '4. close': '6.8100',
#                                         '5. volume': '369600'},
#                          '2000-05-03': {'1. open': '6.5900',
#                                         '2. high': '6.7500',
#                                         '3. low': '6.4700',
#                                         '4. close': '6.5900',
#                                         '5. volume': '299367'},
#                          '2000-05-04': {'1. open': '6.6200',
#                                         '2. high': '6.9400',
#                                         '3. low': '6.6200',
#                                         '4. close': '6.9100',
#                                         '5. volume': '102950'},
#                          '2000-05-05': {'1. open': '6.8800',
#                                         '2. high': '7.5000',
#                                         '3. low': '6.6900',
#                                         '4. close': '7.3700',
#                                         '5. volume': '273067'},
#                          '2000-05-08': {'1. open': '7.5600',
#                                         '2. high': '8.1200',
#                                         '3. low': '7.5000',
#                                         '4. close': '7.5000',
#                                         '5. volume': '536267'},
#                          '2000-05-09': {'1. open': '7.5600',
#                                         '2. high': '7.8800',
#                                         '3. low': '7.0600',
#                                         '4. close': '7.2800',
#                                         '5. volume': '220167'},
#                          '2000-05-10': {'1. open': '5.7500',
#                                         '2. high': '6.2500',
#                                         '3. low': '5.5000',
#                                         '4. close': '6.1300',
#                                         '5. volume': '1973233'},
#                          '2000-05-11': {'1. open': '6.1600',
#                                         '2. high': '6.7500',
#                                         '3. low': '6.0000',
#                                         '4. close': '6.7500',
#                                         '5. volume': '569600'},
#                          '2000-05-12': {'1. open': '6.5600',
#                                         '2. high': '7.1200',
#                                         '3. low': '6.5000',
#                                         '4. close': '6.8800',
#                                         '5. volume': '696017'},
#                          '2000-05-15': {'1. open': '7.0000',
#                                         '2. high': '7.3400',
#                                         '3. low': '6.6900',
#                                         '4. close': '7.3000',
#                                         '5. volume': '513867'},
#                          '2000-05-16': {'1. open': '7.2500',
#                                         '2. high': '7.3100',
#                                         '3. low': '6.8800',
#                                         '4. close': '7.1200',
#                                         '5. volume': '439217'},
#                          '2000-05-17': {'1. open': '6.9400',
#                                         '2. high': '7.0000',
#                                         '3. low': '6.6200',
#                                         '4. close': '7.0000',
#                                         '5. volume': '475833'},
#                          '2000-05-18': {'1. open': '7.0000',
#                                         '2. high': '7.0600',
#                                         '3. low': '6.5600',
#                                         '4. close': '6.6900',
#                                         '5. volume': '530150'},
#                          '2000-05-19': {'1. open': '6.5000',
#                                         '2. high': '6.8100',
#                                         '3. low': '6.5000',
#                                         '4. close': '6.7500',
#                                         '5. volume': '192800'},
#                          '2000-05-22': {'1. open': '6.7500',
#                                         '2. high': '6.7800',
#                                         '3. low': '6.0300',
#                                         '4. close': '6.1300',
#                                         '5. volume': '241433'},
#                          '2000-05-23': {'1. open': '6.1600',
#                                         '2. high': '6.3100',
#                                         '3. low': '6.1600',
#                                         '4. close': '6.2800',
#                                         '5. volume': '114417'},
#                          '2000-05-24': {'1. open': '6.2800',
#                                         '2. high': '6.5000',
#                                         '3. low': '6.0600',
#                                         '4. close': '6.5000',
#                                         '5. volume': '296367'},
#                          '2000-05-25': {'1. open': '6.5600',
#                                         '2. high': '6.6200',
#                                         '3. low': '6.1900',
#                                         '4. close': '6.3100',
#                                         '5. volume': '233067'},
#                          '2000-05-26': {'1. open': '6.2800',
#                                         '2. high': '6.5000',
#                                         '3. low': '5.9400',
#                                         '4. close': '6.1300',
#                                         '5. volume': '145967'},
#                          '2000-05-30': {'1. open': '6.1300',
#                                         '2. high': '6.4400',
#                                         '3. low': '6.1300',
#                                         '4. close': '6.3800',
#                                         '5. volume': '200800'},
#                          '2000-05-31': {'1. open': '6.4100',
#                                         '2. high': '6.4100',
#                                         '3. low': '6.1300',
#                                         '4. close': '6.1900',
#                                         '5. volume': '131467'},
#                          '2000-06-01': {'1. open': '6.1900',
#                                         '2. high': '6.2800',
#                                         '3. low': '6.1600',
#                                         '4. close': '6.1900',
#                                         '5. volume': '207633'},
#                          '2000-06-02': {'1. open': '6.3400',
#                                         '2. high': '7.0600',
#                                         '3. low': '6.1300',
#                                         '4. close': '7.0600',
#                                         '5. volume': '1171567'},
#                          '2000-06-05': {'1. open': '6.7500',
#                                         '2. high': '7.0000',
#                                         '3. low': '5.9400',
#                                         '4. close': '6.8800',
#                                         '5. volume': '253767'},
#                          '2000-06-06': {'1. open': '6.7500',
#                                         '2. high': '6.7500',
#                                         '3. low': '6.5000',
#                                         '4. close': '6.6900',
#                                         '5. volume': '296817'},
#                          '2000-06-07': {'1. open': '6.5200',
#                                         '2. high': '6.6600',
#                                         '3. low': '6.5000',
#                                         '4. close': '6.6200',
#                                         '5. volume': '183750'},
#                          '2000-06-08': {'1. open': '6.6200',
#                                         '2. high': '6.6900',
#                                         '3. low': '6.2200',
#                                         '4. close': '6.6900',
#                                         '5. volume': '211567'},
#                          '2000-06-09': {'1. open': '6.6200',
#                                         '2. high': '6.6900',
#                                         '3. low': '6.5000',
#                                         '4. close': '6.5600',
#                                         '5. volume': '174400'},
#                          '2000-06-12': {'1. open': '6.5900',
#                                         '2. high': '6.6200',
#                                         '3. low': '6.2800',
#                                         '4. close': '6.3100',
#                                         '5. volume': '126833'},
#                          '2000-06-13': {'1. open': '6.3400',
#                                         '2. high': '6.6900',
#                                         '3. low': '6.1300',
#                                         '4. close': '6.2000',
#                                         '5. volume': '145767'},
#                          '2000-06-14': {'1. open': '6.3800',
#                                         '2. high': '6.3800',
#                                         '3. low': '6.1900',
#                                         '4. close': '6.2200',
#                                         '5. volume': '475567'},
#                          '2000-06-15': {'1. open': '6.2500',
#                                         '2. high': '6.3400',
#                                         '3. low': '6.1600',
#                                         '4. close': '6.1900',
#                                         '5. volume': '100633'},
#                          '2000-06-16': {'1. open': '6.3400',
#                                         '2. high': '6.3800',
#                                         '3. low': '5.9400',
#                                         '4. close': '6.1300',
#                                         '5. volume': '259033'},
#                          '2000-06-19': {'1. open': '6.0600',
#                                         '2. high': '6.2500',
#                                         '3. low': '5.9700',
#                                         '4. close': '6.2500',
#                                         '5. volume': '129433'},
#                          '2000-06-20': {'1. open': '6.0000',
#                                         '2. high': '6.1300',
#                                         '3. low': '5.9700',
#                                         '4. close': '6.1300',
#                                         '5. volume': '308367'},
#                          '2000-06-21': {'1. open': '6.0600',
#                                         '2. high': '6.1900',
#                                         '3. low': '6.0000',
#                                         '4. close': '6.0900',
#                                         '5. volume': '113617'},
#                          '2000-06-22': {'1. open': '6.0600',
#                                         '2. high': '6.0900',
#                                         '3. low': '5.9700',
#                                         '4. close': '6.0300',
#                                         '5. volume': '160550'},
#                          '2000-06-23': {'1. open': '6.0000',
#                                         '2. high': '6.0300',
#                                         '3. low': '5.3800',
#                                         '4. close': '5.8700',
#                                         '5. volume': '317967'},
#                          '2000-06-26': {'1. open': '5.9400',
#                                         '2. high': '6.2500',
#                                         '3. low': '5.8700',
#                                         '4. close': '6.2500',
#                                         '5. volume': '280633'},
#                          '2000-06-27': {'1. open': '6.0600',
#                                         '2. high': '6.3100',
#                                         '3. low': '5.9700',
#                                         '4. close': '6.2500',
#                                         '5. volume': '150033'},
#                          '2000-06-28': {'1. open': '6.2700',
#                                         '2. high': '6.3400',
#                                         '3. low': '6.0300',
#                                         '4. close': '6.0600',
#                                         '5. volume': '60550'},
#                          '2000-06-29': {'1. open': '6.0300',
#                                         '2. high': '6.0300',
#                                         '3. low': '5.5000',
#                                         '4. close': '5.6600',
#                                         '5. volume': '300367'},
#                          '2000-06-30': {'1. open': '5.6600',
#                                         '2. high': '6.7500',
#                                         '3. low': '5.6200',
#                                         '4. close': '6.5000',
#                                         '5. volume': '619633'},
#                          '2000-07-03': {'1. open': '6.5000',
#                                         '2. high': '6.5600',
#                                         '3. low': '6.3800',
#                                         '4. close': '6.4400',
#                                         '5. volume': '231367'},
#                          '2000-07-05': {'1. open': '6.5000',
#                                         '2. high': '6.6200',
#                                         '3. low': '6.3400',
#                                         '4. close': '6.3800',
#                                         '5. volume': '124367'},
#                          '2000-07-06': {'1. open': '6.4400',
#                                         '2. high': '6.9400',
#                                         '3. low': '6.3100',
#                                         '4. close': '6.5000',
#                                         '5. volume': '126767'},
#                          '2000-07-07': {'1. open': '6.4400',
#                                         '2. high': '7.2200',
#                                         '3. low': '6.4100',
#                                         '4. close': '7.2200',
#                                         '5. volume': '189433'},
#                          '2000-07-10': {'1. open': '7.0600',
#                                         '2. high': '8.0000',
#                                         '3. low': '6.9400',
#                                         '4. close': '7.8800',
#                                         '5. volume': '311217'},
#                          '2000-07-11': {'1. open': '7.9400',
#                                         '2. high': '8.0000',
#                                         '3. low': '7.0600',
#                                         '4. close': '7.4400',
#                                         '5. volume': '173167'},
#                          '2000-07-12': {'1. open': '7.4400',
#                                         '2. high': '7.9400',
#                                         '3. low': '7.4400',
#                                         '4. close': '7.9400',
#                                         '5. volume': '199467'},
#                          '2000-07-13': {'1. open': '7.7500',
#                                         '2. high': '8.0000',
#                                         '3. low': '7.5000',
#                                         '4. close': '7.7500',
#                                         '5. volume': '594567'},
#                          '2000-07-14': {'1. open': '7.9700',
#                                         '2. high': '8.6200',
#                                         '3. low': '7.8800',
#                                         '4. close': '8.4400',
#                                         '5. volume': '480000'},
#                          '2000-07-17': {'1. open': '8.6900',
#                                         '2. high': '9.0600',
#                                         '3. low': '8.3100',
#                                         '4. close': '8.7500',
#                                         '5. volume': '559033'},
#                          '2000-07-18': {'1. open': '8.9400',
#                                         '2. high': '9.1900',
#                                         '3. low': '8.4400',
#                                         '4. close': '8.9400',
#                                         '5. volume': '185067'},
#                          '2000-07-19': {'1. open': '8.9400',
#                                         '2. high': '9.0600',
#                                         '3. low': '8.0000',
#                                         '4. close': '8.5000',
#                                         '5. volume': '231467'},
#                          '2000-07-20': {'1. open': '8.3400',
#                                         '2. high': '9.1900',
#                                         '3. low': '8.3100',
#                                         '4. close': '8.6200',
#                                         '5. volume': '339567'},
#                          '2000-07-21': {'1. open': '8.6900',
#                                         '2. high': '8.6900',
#                                         '3. low': '8.2200',
#                                         '4. close': '8.4400',
#                                         '5. volume': '237600'},
#                          '2000-07-24': {'1. open': '8.6200',
#                                         '2. high': '8.6200',
#                                         '3. low': '8.3100',
#                                         '4. close': '8.3800',
#                                         '5. volume': '27833'},
#                          '2000-07-25': {'1. open': '8.3800',
#                                         '2. high': '8.4100',
#                                         '3. low': '8.1900',
#                                         '4. close': '8.3100',
#                                         '5. volume': '90150'},
#                          '2000-07-26': {'1. open': '8.1900',
#                                         '2. high': '8.3800',
#                                         '3. low': '7.8100',
#                                         '4. close': '8.2500',
#                                         '5. volume': '75833'},
#                          '2000-07-27': {'1. open': '8.2200',
#                                         '2. high': '8.8700',
#                                         '3. low': '8.2200',
#                                         '4. close': '8.6600',
#                                         '5. volume': '88817'},
#                          '2000-07-28': {'1. open': '8.7200',
#                                         '2. high': '8.7500',
#                                         '3. low': '8.3800',
#                                         '4. close': '8.5000',
#                                         '5. volume': '85767'},
#                          '2000-07-31': {'1. open': '8.5000',
#                                         '2. high': '9.0000',
#                                         '3. low': '8.4100',
#                                         '4. close': '8.7500',
#                                         '5. volume': '157233'},
#                          '2000-08-01': {'1. open': '8.6200',
#                                         '2. high': '8.8700',
#                                         '3. low': '8.2500',
#                                         '4. close': '8.8100',
#                                         '5. volume': '140167'},
#                          '2000-08-02': {'1. open': '8.8700',
#                                         '2. high': '9.0000',
#                                         '3. low': '8.5600',
#                                         '4. close': '8.8700',
#                                         '5. volume': '134233'},
#                          '2000-08-03': {'1. open': '9.0000',
#                                         '2. high': '10.4400',
#                                         '3. low': '8.6200',
#                                         '4. close': '10.1900',
#                                         '5. volume': '685233'},
#                          '2000-08-04': {'1. open': '10.3100',
#                                         '2. high': '11.1200',
#                                         '3. low': '10.2500',
#                                         '4. close': '10.5000',
#                                         '5. volume': '569617'},
#                          '2000-08-07': {'1. open': '10.7500',
#                                         '2. high': '11.1200',
#                                         '3. low': '10.3700',
#                                         '4. close': '11.0000',
#                                         '5. volume': '604800'},
#                          '2000-08-08': {'1. open': '11.0000',
#                                         '2. high': '11.2500',
#                                         '3. low': '10.9400',
#                                         '4. close': '11.0600',
#                                         '5. volume': '308267'},
#                          '2000-08-09': {'1. open': '11.0600',
#                                         '2. high': '13.0600',
#                                         '3. low': '11.0600',
#                                         '4. close': '13.0000',
#                                         '5. volume': '517867'},
#                          '2000-08-10': {'1. open': '12.2500',
#                                         '2. high': '12.5000',
#                                         '3. low': '11.2500',
#                                         '4. close': '11.7500',
# ...
#                          '2017-10-26': {'1. open': '62.2700',
#                                         '2. high': '62.5900',
#                                         '3. low': '61.8800',
#                                         '4. close': '62.0600',
#                                         '5. volume': '4717884'},
#                          '2017-10-27': {'1. open': '62.3600',
#                                         '2. high': '64.2700',
#                                         '3. low': '62.3600',
#                                         '4. close': '64.1400',
#                                         '5. volume': '6158704'},
#                          '2017-10-30': {'1. open': '64.3300',
#                                         '2. high': '65.5800',
#                                         '3. low': '64.2700',
#                                         '4. close': '65.3000',
#                                         '5. volume': '6555910'},
#                          '2017-10-31': {'1. open': '65.3400',
#                                         '2. high': '66.0300',
#                                         '3. low': '64.8600',
#                                         '4. close': '65.4900',
#                                         '5. volume': '6852101'},
#                          '2017-11-01': {'1. open': '65.6900',
#                                         '2. high': '65.7800',
#                                         '3. low': '64.2500',
#                                         '4. close': '65.3300',
#                                         '5. volume': '5109759'},
#                          '2017-11-02': {'1. open': '65.4100',
#                                         '2. high': '65.8400',
#                                         '3. low': '64.8300',
#                                         '4. close': '65.4500',
#                                         '5. volume': '5587306'},
#                          '2017-11-03': {'1. open': '66.8700',
#                                         '2. high': '67.0300',
#                                         '3. low': '62.1100',
#                                         '4. close': '63.2000',
#                                         '5. volume': '18650840'},
#                          '2017-11-06': {'1. open': '63.4100',
#                                         '2. high': '63.7200',
#                                         '3. low': '60.7100',
#                                         '4. close': '60.8700',
#                                         '5. volume': '12925543'},
#                          '2017-11-07': {'1. open': '61.0900',
#                                         '2. high': '61.3500',
#                                         '3. low': '60.1000',
#                                         '4. close': '60.9600',
#                                         '5. volume': '7200634'},
#                          '2017-11-08': {'1. open': '62.5000',
#                                         '2. high': '64.9000',
#                                         '3. low': '62.1500',
#                                         '4. close': '64.5500',
#                                         '5. volume': '12604699'},
#                          '2017-11-09': {'1. open': '63.4900',
#                                         '2. high': '64.1800',
#                                         '3. low': '62.5900',
#                                         '4. close': '63.3100',
#                                         '5. volume': '5195422'},
#                          '2017-11-10': {'1. open': '62.8700',
#                                         '2. high': '63.0700',
#                                         '3. low': '62.2500',
#                                         '4. close': '63.0000',
#                                         '5. volume': '4809846'},
#                          '2017-11-13': {'1. open': '62.7200',
#                                         '2. high': '63.9700',
#                                         '3. low': '62.6700',
#                                         '4. close': '63.6200',
#                                         '5. volume': '3019231'},
#                          '2017-11-14': {'1. open': '63.3700',
#                                         '2. high': '64.4000',
#                                         '3. low': '62.7900',
#                                         '4. close': '64.0300',
#                                         '5. volume': '4344145'},
#                          '2017-11-15': {'1. open': '63.4300',
#                                         '2. high': '63.6700',
#                                         '3. low': '62.5000',
#                                         '4. close': '62.8900',
#                                         '5. volume': '4101191'},
#                          '2017-11-16': {'1. open': '63.1300',
#                                         '2. high': '64.4100',
#                                         '3. low': '63.0400',
#                                         '4. close': '64.1300',
#                                         '5. volume': '4325436'},
#                          '2017-11-17': {'1. open': '64.0000',
#                                         '2. high': '64.4400',
#                                         '3. low': '63.1800',
#                                         '4. close': '64.1000',
#                                         '5. volume': '4116771'},
#                          '2017-11-20': {'1. open': '63.9300',
#                                         '2. high': '64.1800',
#                                         '3. low': '63.2800',
#                                         '4. close': '63.9300',
#                                         '5. volume': '3115714'},
#                          '2017-11-21': {'1. open': '64.4900',
#                                         '2. high': '64.9500',
#                                         '3. low': '64.1900',
#                                         '4. close': '64.5000',
#                                         '5. volume': '3542389'},
#                          '2017-11-22': {'1. open': '64.9100',
#                                         '2. high': '66.3100',
#                                         '3. low': '64.8900',
#                                         '4. close': '65.1400',
#                                         '5. volume': '5711411'},
#                          '2017-11-24': {'1. open': '65.1800',
#                                         '2. high': '66.1400',
#                                         '3. low': '65.1200',
#                                         '4. close': '66.0300',
#                                         '5. volume': '1644818'},
#                          '2017-11-27': {'1. open': '66.1800',
#                                         '2. high': '66.4500',
#                                         '3. low': '65.6300',
#                                         '4. close': '65.7400',
#                                         '5. volume': '4079998'},
#                          '2017-11-28': {'1. open': '66.0200',
#                                         '2. high': '66.4600',
#                                         '3. low': '65.8400',
#                                         '4. close': '65.9700',
#                                         '5. volume': '3336450'},
#                          '2017-11-29': {'1. open': '65.6100',
#                                         '2. high': '65.7100',
#                                         '3. low': '61.9500',
#                                         '4. close': '62.0100',
#                                         '5. volume': '9258335'},
#                          '2017-11-30': {'1. open': '62.5500',
#                                         '2. high': '62.7300',
#                                         '3. low': '60.8600',
#                                         '4. close': '62.4000',
#                                         '5. volume': '8942328'},
#                          '2017-12-01': {'1. open': '61.9600',
#                                         '2. high': '62.6900',
#                                         '3. low': '60.7128',
#                                         '4. close': '61.9600',
#                                         '5. volume': '5414035'},
#                          '2017-12-04': {'1. open': '62.3900',
#                                         '2. high': '62.4800',
#                                         '3. low': '58.3500',
#                                         '4. close': '58.6000',
#                                         '5. volume': '12287139'},
#                          '2017-12-05': {'1. open': '57.6350',
#                                         '2. high': '60.7200',
#                                         '3. low': '57.2900',
#                                         '4. close': '59.5500',
#                                         '5. volume': '7587949'},
#                          '2017-12-06': {'1. open': '59.4800',
#                                         '2. high': '60.8100',
#                                         '3. low': '58.6300',
#                                         '4. close': '60.7500',
#                                         '5. volume': '8237480'},
#                          '2017-12-07': {'1. open': '60.8000',
#                                         '2. high': '62.4500',
#                                         '3. low': '60.6900',
#                                         '4. close': '61.5700',
#                                         '5. volume': '6940997'},
#                          '2017-12-08': {'1. open': '62.2600',
#                                         '2. high': '63.5100',
#                                         '3. low': '62.0403',
#                                         '4. close': '62.4300',
#                                         '5. volume': '5742404'},
#                          '2017-12-11': {'1. open': '62.1400',
#                                         '2. high': '63.1800',
#                                         '3. low': '62.1400',
#                                         '4. close': '63.1700',
#                                         '5. volume': '3495142'},
#                          '2017-12-12': {'1. open': '64.1100',
#                                         '2. high': '64.6900',
#                                         '3. low': '63.2000',
#                                         '4. close': '64.4000',
#                                         '5. volume': '6413495'},
#                          '2017-12-13': {'1. open': '64.8500',
#                                         '2. high': '65.2800',
#                                         '3. low': '64.3000',
#                                         '4. close': '64.6000',
#                                         '5. volume': '5405265'},
#                          '2017-12-14': {'1. open': '64.7000',
#                                         '2. high': '65.4500',
#                                         '3. low': '64.5400',
#                                         '4. close': '65.0300',
#                                         '5. volume': '4683251'},
#                          '2017-12-15': {'1. open': '65.4700',
#                                         '2. high': '67.0000',
#                                         '3. low': '64.9900',
#                                         '4. close': '66.7300',
#                                         '5. volume': '9306372'},
#                          '2017-12-18': {'1. open': '67.0800',
#                                         '2. high': '67.4000',
#                                         '3. low': '65.8800',
#                                         '4. close': '66.0100',
#                                         '5. volume': '6179536'},
#                          '2017-12-19': {'1. open': '66.1000',
#                                         '2. high': '66.2500',
#                                         '3. low': '64.3901',
#                                         '4. close': '64.9000',
#                                         '5. volume': '5928911'},
#                          '2017-12-20': {'1. open': '65.3100',
#                                         '2. high': '65.4400',
#                                         '3. low': '64.0061',
#                                         '4. close': '64.3800',
#                                         '5. volume': '4676308'},
#                          '2017-12-21': {'1. open': '64.5100',
#                                         '2. high': '65.2000',
#                                         '3. low': '64.1400',
#                                         '4. close': '65.0800',
#                                         '5. volume': '3333438'},
#                          '2017-12-22': {'1. open': '64.8600',
#                                         '2. high': '64.9500',
#                                         '3. low': '64.3800',
#                                         '4. close': '64.5100',
#                                         '5. volume': '3297781'},
#                          '2017-12-26': {'1. open': '64.2400',
#                                         '2. high': '64.4700',
#                                         '3. low': '63.3800',
#                                         '4. close': '63.4500',
#                                         '5. volume': '3203245'},
#                          '2017-12-27': {'1. open': '63.6700',
#                                         '2. high': '63.7399',
#                                         '3. low': '63.0700',
#                                         '4. close': '63.3400',
#                                         '5. volume': '4764842'},
#                          '2017-12-28': {'1. open': '63.3400',
#                                         '2. high': '63.5000',
#                                         '3. low': '62.6001',
#                                         '4. close': '63.4000',
#                                         '5. volume': '3102865'},
#                          '2017-12-29': {'1. open': '63.5900',
#                                         '2. high': '63.8300',
#                                         '3. low': '63.1200',
#                                         '4. close': '63.3200',
#                                         '5. volume': '3188465'},
#                          '2018-01-02': {'1. open': '63.5400',
#                                         '2. high': '64.6700',
#                                         '3. low': '63.3700',
#                                         '4. close': '64.3100',
#                                         '5. volume': '5118509'},
#                          '2018-01-03': {'1. open': '64.5500',
#                                         '2. high': '65.7450',
#                                         '3. low': '64.3955',
#                                         '4. close': '65.3100',
#                                         '5. volume': '4333169'},
#                          '2018-01-04': {'1. open': '65.7500',
#                                         '2. high': '65.8700',
#                                         '3. low': '64.3600',
#                                         '4. close': '64.6600',
#                                         '5. volume': '3896685'},
#                          '2018-01-05': {'1. open': '64.8800',
#                                         '2. high': '66.4700',
#                                         '3. low': '64.4900',
#                                         '4. close': '66.3700',
#                                         '5. volume': '4969918'},
#                          '2018-01-08': {'1. open': '66.4900',
#                                         '2. high': '67.2700',
#                                         '3. low': '65.6500',
#                                         '4. close': '66.6300',
#                                         '5. volume': '4502299'},
#                          '2018-01-09': {'1. open': '66.7500',
#                                         '2. high': '66.7500',
#                                         '3. low': '64.9000',
#                                         '4. close': '66.1900',
#                                         '5. volume': '5995943'}}}

# %%
mydictionary = page.json()

df = pd.DataFrame.from_dict(mydictionary["Time Series (Daily)"], orient='index')

print(df.iloc[1:10])

df = df.reset_index()
df = df.sort_index(ascending=False)
df = df.reset_index()
df.head()
# Out:
#             1. open  2. high   3. low 4. close 5. volume
# 2000-01-04  16.1200  16.2500  14.2500  15.9400    355200
# 2000-01-05  15.8100  16.3700  15.7500  16.0000    282417
# 2000-01-06  15.8800  16.0000  15.5600  15.6900    202417
# 2000-01-07  15.8800  16.2500  15.5000  16.1200   1295750
# 2000-01-10  16.2500  17.0000  15.8800  16.9400    912550
# 2000-01-11  17.0000  18.2500  16.8800  17.6900    892550
# 2000-01-12  17.2500  17.2500  16.3700  16.9400    224017
# 2000-01-13  16.8800  17.2500  16.5000  17.1200    272267
# 2000-01-14  16.8800  17.1200  16.6900  16.9400    212817
#    level_0       index  1. open  2. high   3. low 4. close 5. volume
# 0     4533  2018-01-09  66.7500  66.7500  64.9000  66.1900   5995943
# 1     4532  2018-01-08  66.4900  67.2700  65.6500  66.6300   4502299
# 2     4531  2018-01-05  64.8800  66.4700  64.4900  66.3700   4969918
# 3     4530  2018-01-04  65.7500  65.8700  64.3600  64.6600   3896685
# 4     4529  2018-01-03  64.5500  65.7450  64.3955  65.3100   4333169

# %%
month = []
day=[]
year = []
for index, row in df.iterrows():
    a = row["index"]
    datee = datetime.strptime(a, "%Y-%m-%d")
    monthdate = datee.strftime("%B")
    daydate = datee.strftime("%A") 
    yeardate = datee.strftime("%Y") 
    month.append(monthdate)
    year.append(yeardate)
    day.append(daydate) 

df["Month"] = month
df["Day"] = day
df["Year"]= year
df["Company"] = symbol
df.head()
# Out:
#    level_0       index  1. open  2. high   3. low 4. close 5. volume    Month  \
# 0     4533  2018-01-09  66.7500  66.7500  64.9000  66.1900   5995943  January
# 1     4532  2018-01-08  66.4900  67.2700  65.6500  66.6300   4502299  January
# 2     4531  2018-01-05  64.8800  66.4700  64.4900  66.3700   4969918  January
# 3     4530  2018-01-04  65.7500  65.8700  64.3600  64.6600   3896685  January
# 4     4529  2018-01-03  64.5500  65.7450  64.3955  65.3100   4333169  January
#
#          Day  Year Company
# 0    Tuesday  2018    ATVI
# 1     Monday  2018    ATVI
# 2     Friday  2018    ATVI
# 3   Thursday  2018    ATVI
# 4  Wednesday  2018    ATVI

# %%
change = []

counter = 0
while counter < (len(df["index"]) -1) :
    new = df["4. close"][counter]
    old = df["4. close"][counter + 1]
    calc = (float(new) - float(old)) / float(old)
    change.append(calc)
    counter += 1

change.append(0)
df["daily change"] = change
df.head()
# Out:
#    level_0       index  1. open  2. high   3. low 4. close 5. volume    Month  \
# 0     4533  2018-01-09  66.7500  66.7500  64.9000  66.1900   5995943  January
# 1     4532  2018-01-08  66.4900  67.2700  65.6500  66.6300   4502299  January
# 2     4531  2018-01-05  64.8800  66.4700  64.4900  66.3700   4969918  January
# 3     4530  2018-01-04  65.7500  65.8700  64.3600  64.6600   3896685  January
# 4     4529  2018-01-03  64.5500  65.7450  64.3955  65.3100   4333169  January
#
#          Day  Year Company  daily change
# 0    Tuesday  2018    ATVI     -0.006604
# 1     Monday  2018    ATVI      0.003917
# 2     Friday  2018    ATVI      0.026446
# 3   Thursday  2018    ATVI     -0.009953
# 4  Wednesday  2018    ATVI      0.015550

# %%
df["Year"] = df["Year"].apply(pd.to_numeric)
df["5. volume"] = df["5. volume"].apply(pd.to_numeric)
df.head()
# Out:
#    level_0       index  1. open  2. high   3. low 4. close  5. volume  \
# 0     4533  2018-01-09  66.7500  66.7500  64.9000  66.1900    5995943
# 1     4532  2018-01-08  66.4900  67.2700  65.6500  66.6300    4502299
# 2     4531  2018-01-05  64.8800  66.4700  64.4900  66.3700    4969918
# 3     4530  2018-01-04  65.7500  65.8700  64.3600  64.6600    3896685
# 4     4529  2018-01-03  64.5500  65.7450  64.3955  65.3100    4333169
#
#      Month        Day  Year Company  daily change
# 0  January    Tuesday  2018    ATVI     -0.006604
# 1  January     Monday  2018    ATVI      0.003917
# 2  January     Friday  2018    ATVI      0.026446
# 3  January   Thursday  2018    ATVI     -0.009953
# 4  January  Wednesday  2018    ATVI      0.015550

# %%
above_df = df.loc[df["Year"] >= 2014, :]
below_df = above_df.loc[(above_df["Year"] < 2018), :]
master_df = below_df
del master_df["level_0"]
master_df = master_df.reset_index()
master_df.head()
# Out:
#    level_0       index  1. open  2. high   3. low 4. close  5. volume  \
# 0        6  2017-12-29  63.5900  63.8300  63.1200  63.3200    3188465
# 1        7  2017-12-28  63.3400  63.5000  62.6001  63.4000    3102865
# 2        8  2017-12-27  63.6700  63.7399  63.0700  63.3400    4764842
# 3        9  2017-12-26  64.2400  64.4700  63.3800  63.4500    3203245
# 4       10  2017-12-22  64.8600  64.9500  64.3800  64.5100    3297781
#
#       Month        Day  Year Company  daily change
# 0  December     Friday  2017    ATVI     -0.001262
# 1  December   Thursday  2017    ATVI      0.000947
# 2  December  Wednesday  2017    ATVI     -0.001734
# 3  December    Tuesday  2017    ATVI     -0.016432
# 4  December     Friday  2017    ATVI     -0.008758

# %%
day_to_num = []
month_to_num = []

x = 0

while x < len(master_df["Day"]):
    
    if master_df["Day"][x] == "Monday":
        day_to_num.append(1)
    elif master_df["Day"][x] == "Tuesday":
        day_to_num.append(2)
    elif master_df["Day"][x] == "Wednesday":
        day_to_num.append(3)
    elif master_df["Day"][x] == "Thursday":
        day_to_num.append(4)
    else:
        day_to_num.append(5)
        
    x += 1

z = 0

while z < len(master_df["Month"]):
    
    if master_df["Month"][z] == "January":
        month_to_num.append(1)
    elif master_df["Month"][z] == "February":
        month_to_num.append(2)
    elif master_df["Month"][z] == "March":
        month_to_num.append(3)
    elif master_df["Month"][z] == "April":
        month_to_num.append(4)
    elif master_df["Month"][z] == "May":
        month_to_num.append(5)
    elif master_df["Month"][z] == "June":
        month_to_num.append(6)
    elif master_df["Month"][z] == "July":
        month_to_num.append(7)
    elif master_df["Month"][z] == "August":
        month_to_num.append(8)
    elif master_df["Month"][z] == "September":
        month_to_num.append(9)
    elif master_df["Month"][z] == "October":
        month_to_num.append(10)
    elif master_df["Month"][z] == "November":
        month_to_num.append(11)
    else:
        month_to_num.append(12)
        
    z += 1

master_df["Date to Num"] = day_to_num
master_df["Month to Num"] = month_to_num
master_df.head()
# Out:
#    level_0       index  1. open  2. high   3. low 4. close  5. volume  \
# 0        6  2017-12-29  63.5900  63.8300  63.1200  63.3200    3188465
# 1        7  2017-12-28  63.3400  63.5000  62.6001  63.4000    3102865
# 2        8  2017-12-27  63.6700  63.7399  63.0700  63.3400    4764842
# 3        9  2017-12-26  64.2400  64.4700  63.3800  63.4500    3203245
# 4       10  2017-12-22  64.8600  64.9500  64.3800  64.5100    3297781
#
#       Month        Day  Year Company  daily change  Date to Num  Month to Num
# 0  December     Friday  2017    ATVI     -0.001262            5            12
# 1  December   Thursday  2017    ATVI      0.000947            4            12
# 2  December  Wednesday  2017    ATVI     -0.001734            3            12
# 3  December    Tuesday  2017    ATVI     -0.016432            2            12
# 4  December     Friday  2017    ATVI     -0.008758            5            12

# %%
day_change = master_df.groupby(["Date to Num"])

MeanofChange = (day_change["daily change"].mean()) * 100
SumofVol = day_change["5. volume"].sum()

DayGrouped = pd.DataFrame({"Daily Change Average" : MeanofChange,
                       "Total Volume" : SumofVol})

DayGrouped["Daily Change Average"] = DayGrouped["Daily Change Average"].map("{:.4f}%".format)
DayGrouped.head()
# Out:
#             Daily Change Average  Total Volume
# Date to Num
# 1                       -0.1486%    1271558291
# 2                        0.1248%    1499281524
# 3                        0.4148%    1588084169
# 4                        0.1547%    1476141844
# 5                        0.1417%    1780367600

# %%
month_change = master_df.groupby(["Month to Num"])

mMeanofChange = (month_change["daily change"].mean()) * 100
mSumofVol = month_change["5. volume"].sum()

MonthGrouped = pd.DataFrame({"Monthly Change Average" : mMeanofChange,
                       "Total Volume" : mSumofVol})

MonthGrouped["Monthly Change Average"] = MonthGrouped["Monthly Change Average"].map("{:.4f}%".format)
MonthGrouped.head(12)
# Out:
#              Monthly Change Average  Total Volume
# Month to Num
# 1                           0.0153%     692395002
# 2                           0.3812%     775882071
# 3                           0.2290%     548191996
# 4                           0.0673%     375016837
# 5                           0.4771%     611883037
# 6                           0.0346%     700425245
# 7                           0.1882%     521054372
# 8                           0.2984%     734942471
# 9                           0.0154%     689871615
# 10                          0.0869%     618853836
# 11                         -0.0364%     820332236
# 12                         -0.0388%     526584710

# %%
master_df.to_csv(symbol + "final.csv")
