# %%
import pandas as pd 
import datetime 
from datetime import datetime

# %%
Akey = "FS9AIROSBH4ZBEHY"

start_url = "https://www.alphavantage.co/query?"
function = "TIME_SERIES_MONTHLY"
stock = "FB"
begin_date = "2018-01-05"
end_date = "2015-01-05"

# query = url + "api-key=" + api_key + "&q=" + q + "&begin_date=" + begin_date\
#     + "&end_date=" + end_date

url = start_url + "function=" + function + "&symbol=" + stock + "&apikey=" + Akey + "&begin_date=" + begin_date\
    + "&end_date=" + end_date

get = requests.get(url)
getJ = get.json()
print(json.dumps(getJ, indent=4))
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Monthly Prices (open, high, low, close) and Volumes",
#         "2. Symbol": "FB",
#         "3. Last Refreshed": "2018-01-05",
#         "4. Time Zone": "US/Eastern"
#     },
#     "Monthly Time Series": {
#         "2018-01-05": {
#             "1. open": "177.6800",
#             "2. high": "186.9000",
#             "3. low": "177.5500",
#             "4. close": "186.8500",
#             "5. volume": "60887131"
#         },
#         "2017-12-29": {
#             "1. open": "176.0300",
#             "2. high": "182.2800",
#             "3. low": "169.0100",
#             "4. close": "176.4600",
#             "5. volume": "308647940"
#         },
#         "2017-11-30": {
#             "1. open": "182.3600",
#             "2. high": "184.2500",
#             "3. low": "174.0000",
#             "4. close": "177.1800",
#             "5. volume": "335337226"
#         },
#         "2017-10-31": {
# ...

# %%
mydictionary = page.json()
df = pd.DataFrame.from_dict(getJ["Monthly Time Series"], orient='index', )
df = pd.DataFrame.from_dict(getJ["Meta Data"], orient='index',)
df = df.reset_index()
df = df.sort_index(ascending=False)
df.head()
# Out:
#                index                                                  0
# 3       4. Time Zone                                         US/Eastern
# 2  3. Last Refreshed                                         2018-01-05
# 1          2. Symbol                                                 FB
# 0     1. Information  Monthly Prices (open, high, low, close) and Vo...

# %%
month = []
year = []
counter = 0
while counter < len(df["index"]):
    
    test = df["index"][counter]
    converted_time = datetime.strptime(test, "%Y-%m-%d")
    mydate = datetime.date(converted_time)
    month.append(mydate.strftime("%B"))
    year.append(mydate.strftime("%Y"))
    counter += 1

df["month"] = month
df["year"] = year
df.head()
# Out:
#          index   1. open   2. high    3. low  4. close  5. volume      month  \
# 67  2018-01-05  177.6800  186.9000  177.5500  186.8500   60887131       June
# 66  2017-12-29  176.0300  182.2800  169.0100  176.4600  308647940       July
# 65  2017-11-30  182.3600  184.2500  174.0000  177.1800  335337226     August
# 64  2017-10-31  171.3900  180.8000  168.2900  180.0600  309836859  September
# 63  2017-09-29  172.4000  174.0000  161.5600  170.8700  300559928    October
#
#     year
# 67  2012
# 66  2012
# 65  2012
# 64  2012
# 63  2012

# %%
# Using .rename(columns={}) in order to rename columns
renamed_df = df.rename(columns={"index":"date"})
renamed_df.head()
# Out:
#           date   1. open   2. high    3. low  4. close  5. volume      month
# 67  2018-01-05  177.6800  186.9000  177.5500  186.8500   60887131       June
# 66  2017-12-29  176.0300  182.2800  169.0100  176.4600  308647940       July
# 65  2017-11-30  182.3600  184.2500  174.0000  177.1800  335337226     August
# 64  2017-10-31  171.3900  180.8000  168.2900  180.0600  309836859  September
# 63  2017-09-29  172.4000  174.0000  161.5600  170.8700  300559928    October

# %%
# Convert tweet timestamps to datetime objects that can be manipulated by Python
raw_time = renamed_df["date"]
converted_time = datetime.strptime(raw_time, "%Y-%m-%d")
mydate = datetime.date(converted_time)  #year, month, day
print(mydate.strftime("%B"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-2e03768e5bd8> in <module>()
#       1 # Convert tweet timestamps to datetime objects that can be manipulated by Python
#       2 raw_time = renamed_df["date"]
# ----> 3 converted_time = datetime.strptime(raw_time, "%Y-%m-%d")
#       4 mydate = datetime.date(converted_time)  #year, month, day
#       5 print(mydate.strftime("%B"))
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
# print csv 

file_one_df.to_csv("Output/fileOne.csv", index=False, header=True)
